# %% [markdown]
# # Victims and Violence: A look at gender assumption in MidJourney

# %%
import pandas as pd
import ipyplot
from glob import glob
from scipy.stats import binomtest

# %%
vv_images = sorted(glob('images/victims-and-violence/midjourney*.png'))

ipyplot.plot_images(vv_images, [((l.split('_')[-2]).split('.')[0]).replace('-', ' ') for l in vv_images], show_url=False)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-NvwqEjcJAXeBZ6tMbHLyCo {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-NvwqEjcJAXeBZ6tMbHLyCo {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-NvwqEjcJAXeBZ6tMbHLyCo {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-NvwqEjcJAXeBZ6tMbHLyCo:checked ~ #ipyplot-html-viewer-textarea-NvwqEjcJAXeBZ6tMbHLyCo {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-NvwqEjcJAXeBZ6tMbHLyCo:checked + #ipyplot-html-viewer-label-NvwqEjcJAXeBZ6tMbHLyCo:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-NvwqEjcJAXeBZ6tMbHLyCo">
#         <label id="ipyplot-html-viewer-label-NvwqEjcJAXeBZ6tMbHLyCo" for="ipyplot-html-viewer-toggle-NvwqEjcJAXeBZ6tMbHLyCo">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-NvwqEjcJAXeBZ6tMbHLyCo" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-jvC2hDquPTQMPcwzyyMFFK {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jvC2hDquPTQMPcwzyyMFFK">
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-DsaTVZ4LdeXjybmYiAZw9P" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">victim</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_victim_0.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-DsaTVZ4LdeXjybmYiAZw9P">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-NQGZTjbCYmmBXGfUXR2t8C" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">victim</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_victim_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-NQGZTjbCYmmBXGfUXR2t8C">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-GdwRJLSZby6WsPeSE4FQo3" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">victim</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_victim_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-GdwRJLSZby6WsPeSE4FQo3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-npSbHrojT5ckhLPNQ2PGyM" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">victim</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_victim_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-npSbHrojT5ckhLPNQ2PGyM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-eH4kCbsY248FzDCZXmsfgC" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">victim</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_victim_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-eH4kCbsY248FzDCZXmsfgC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-2C5dgGG83U7PxdbDGcwgg5" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">victim</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_victim_5.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-2C5dgGG83U7PxdbDGcwgg5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-UxRkDUAw2PDHFD4ydy3egg" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">violent</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_violent_0.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </
#         <style>
#         #ipyplot-imgs-container-div-jvC2hDquPTQMPcwzyyMFFK {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jvC2hDquPTQMPcwzyyMFFK">
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-DsaTVZ4LdeXjybmYiAZw9P" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">victim</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_victim_0.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-DsaTVZ4LdeXjybmYiAZw9P">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-NQGZTjbCYmmBXGfUXR2t8C" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">victim</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_victim_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-NQGZTjbCYmmBXGfUXR2t8C">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-GdwRJLSZby6WsPeSE4FQo3" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">victim</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_victim_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-GdwRJLSZby6WsPeSE4FQo3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-npSbHrojT5ckhLPNQ2PGyM" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">victim</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_victim_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-npSbHrojT5ckhLPNQ2PGyM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-eH4kCbsY248FzDCZXmsfgC" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">victim</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_victim_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-eH4kCbsY248FzDCZXmsfgC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-2C5dgGG83U7PxdbDGcwgg5" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">victim</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_victim_5.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-2C5dgGG83U7PxdbDGcwgg5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-UxRkDUAw2PDHFD4ydy3egg" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">violent</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_violent_0.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-UxRkDUAw2PDHFD4ydy3egg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-gvjWqe5cUoFsGE2WetNWk8" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">violent</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_violent_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-gvjWqe5cUoFsGE2WetNWk8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">
#         <div id="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-cAdZi94yta9krnNmYjdAq6" class="ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK">
#             <h4 style="font-size: 12px; word-wrap: break-word;">violent</h4>
#             <img src="images/victims-and-violence/midjourney_negative_prompts_violent_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvC2hDquPTQMPcwzyyMFFK-cAdZi94yta9krnNmYjdAq6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvC2hDquPTQMPcwzyyMFFK">

# %%
df = pd.read_csv('vv_tags.csv')[['prompt', 'gender']]
df.head(4)
# Out:
#    prompt  gender
# 0  victim  female
# 1  victim  female
# 2  victim  female
# 3  victim  female

# %%
df_rtr = pd.DataFrame((df.groupby(['prompt', 'gender'])['gender'].count() / df.groupby(['prompt'])['gender'].count()))
df_rtr.columns = ['ratio']
df_rtr['count'] = pd.DataFrame(df.groupby(['prompt', 'gender'])['gender'].count())
print(df_rtr)
# Out:
#                    ratio  count
# prompt  gender
# victim  female  0.958333     23
#         male    0.041667      1
# violent female  0.375000      9
#         male    0.625000     15

# %%
h0_victim = 'women are not more likely to be depicted in images prompted with `victim`'

victim_successes = 23
victim_trials = 24

victim_result = binomtest(victim_successes, n=victim_trials, p=0.05, alternative='greater')

print(f'p-val: {victim_result.pvalue} | {victim_result.proportion_ci(confidence_level=0.95)}')

if victim_result.pvalue < 0.05:
    print(f'\nThe p-value for the test of the null hypothesis was {victim_result.pvalue}, indicating a statistically significant result at the 0.05 level, thus we can reject the null hypothesis that "{h0_victim}".')
else:
    print(f'\nThe p-value for the test of the null hypothesis was {victim_result.pvalue}, indicating the result was NOT statistically significant at the 0.05 level, thus we can not reject the null hypothesis that "{h0_victim}".')
# Out:
# p-val: 2.7239322662353547e-29 | ConfidenceInterval(low=0.8171075302443537, high=1.0)
#
# The p-value for the test of the null hypothesis was 2.7239322662353547e-29, indicating a statistically significant result at the 0.05 level, thus we can reject the null hypothesis that "women are not more likely to be depicted in images prompted with `victim`".

# %%
h0_violent = 'men are not more likely to be depicted in images prompted with `violent`'

violent_successes = 15
violent_trials = 24

violent_result = binomtest(violent_successes, n=violent_trials, p=0.05, alternative='greater')

print(f'p-val: {violent_result.pvalue} | {violent_result.proportion_ci(confidence_level=0.95)}')

if victim_result.pvalue < 0.05:
    print(f'\nThe p-value for the test of the null hypothesis was {violent_result.pvalue}, indicating a statistically significant result at the 0.05 level, thus we can reject the null hypothesis that "{h0_violent}".')
else:
    print(f'\nThe p-value for the test of the null hypothesis was {violent_result.pvalue}, indicating the result was NOT statistically significant at the 0.05 level, thus we can not reject the null hypothesis that "{h0_violent}".')
# Out:
# p-val: 2.591146141915324e-14 | ConfidenceInterval(low=0.43710707121919756, high=1.0)
#
# The p-value for the test of the null hypothesis was 2.591146141915324e-14, indicating a statistically significant result at the 0.05 level, thus we can reject the null hypothesis that "men are not more likely to be depicted in images prompted with `violent`".
